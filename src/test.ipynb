# %%
import pandas as pd
import geopandas as gpd
import matplotlib

# %%
from shapely.geometry import Polygon, Point

# %%
from geopy.geocoders import Nominatim
from geopy.geocoders import GoogleV3

# %%
states = gpd.read_file("..\\data\\States\\gz_2010_us_040_00_5m\\gz_2010_us_040_00_5m.shp")

# %%
states.head()
# Out:
#         GEO_ID STATE        NAME  LSAD  CENSUSAREA  \
# 0  0400000US01    01     Alabama  None   50645.326
# 1  0400000US02    02      Alaska  None  570640.950
# 2  0400000US04    04     Arizona  None  113594.084
# 3  0400000US05    05    Arkansas  None   52035.477
# 4  0400000US06    06  California  None  155779.220
#
#                                             geometry
# 0  MULTIPOLYGON (((-88.12466 30.28364, -88.08681 ...
# 1  MULTIPOLYGON (((-166.10574 53.98861, -166.0752...
# 2  POLYGON ((-112.53859 37.00067, -112.53454 37.0...
# 3  POLYGON ((-94.04296 33.01922, -94.04304 33.079...
# 4  MULTIPOLYGON (((-122.42144 37.86997, -122.4213...

# %%
ax = states.to_crs(epsg=5071).plot(figsize=(20,20), color="#CCCCCC",edgecolor="#FF0000",linewidth=0.2)
