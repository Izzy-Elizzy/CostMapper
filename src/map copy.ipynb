# %%
import pandas as pd
import geopandas as gpd

housing_prices = pd.read_csv("..\\data\\2023-q4-county-median-prices-and-monthly-mortgage-payment-by-price-03-19-2024.csv")

counties = gpd.read_file("..\\data\\Countys\\gz_2010_us_050_00_5m\\gz_2010_us_050_00_5m.shp")

# %% [markdown]
# Split County Name into COUNTY and STATE in housing_prices

# %%
housing_prices[["COUNTY","STATE"]] = housing_prices['County Name'].str.split(", ", expand=True)
housing_prices['COUNTY'] = housing_prices['COUNTY'].str.replace(' County', '')

# %%
state_abbrev = {
    ' Alabama': 'AL', ' Alaska': 'AK', ' Arizona': 'AZ', ' Arkansas': 'AR', ' California': 'CA',
    ' Colorado': 'CO', ' Connecticut': 'CT', ' Delaware': 'DE', ' Florida': 'FL', ' Georgia': 'GA',
    ' Hawaii': 'HI', ' Idaho': 'ID', ' Illinois': 'IL', ' Indiana': 'IN', ' Iowa': 'IA',
    ' Kansas': 'KS', ' Kentucky': 'KY', ' Louisiana': 'LA', ' Maine': 'ME', ' Maryland': 'MD',
    ' Massachusetts': 'MA', ' Michigan': 'MI', ' Minnesota': 'MN', ' Mississippi': 'MS', ' Missouri': 'MO',
    ' Montana': 'MT', ' Nebraska': 'NE', ' Nevada': 'NV', ' New Hampshire': 'NH', ' New Jersey': 'NJ',
    ' New Mexico': 'NM', ' New York': 'NY', ' North Carolina': 'NC', ' North Dakota': 'ND', ' Ohio': 'OH',
    ' Oklahoma': 'OK', ' Oregon': 'OR', ' Pennsylvania': 'PA', ' Rhode Island': 'RI', ' South Carolina': 'SC',
    ' South Dakota': 'SD', ' Tennessee': 'TN', ' Texas': 'TX', ' Utah': 'UT', ' Vermont': 'VT',
    ' Virginia': 'VA', ' Washington': 'WA', ' West Virginia': 'WV', ' Wisconsin': 'WI', ' Wyoming': 'WY'
}


# Replace full state names with abbreviations in the housing_prices DataFrame
housing_prices['STATE'] = housing_prices['STATE'].replace(state_abbrev)

# %%
# Create a unique identifier for each county by combining county and state
housing_prices['COUNTY_ID'] = housing_prices['COUNTY'] + ', ' + housing_prices['STATE']

# %%
# Drop the original "County Name" column
housing_prices = housing_prices.drop('County Name', axis=1)

# %%
housing_prices
# Out:
#      Median Home Price Q4 2023 Monthly Payment Q4 2023  \
# 0                  $1,575,350                  $9,720
# 1                  $1,553,450                  $9,580
# 2                  $1,456,190                  $8,980
# 3                  $1,334,250                  $8,230
# 4                  $1,181,140                  $7,290
# ...                        ...                     ...
# 3100                  $56,440                    $350
# 3101                  $53,040                    $330
# 3102                  $50,740                    $310
# 3103                  $49,530                    $310
# 3104                  $42,660                    $260
#
#      Monthly Payment Q4 2022         COUNTY STATE          COUNTY_ID
# 0                    $9,210       San Mateo    CA      San Mateo, CA
# 1                    $8,570     Santa Clara    CA    Santa Clara, CA
# 2                    $8,520           Marin    CA          Marin, CA
# 3                    $7,800   San Francisco    CA  San Francisco, CA
# 4                    $6,610           Teton    WY          Teton, WY
# ...                      ...            ...   ...                ...
# 3100                   $320       Stonewall    TX      Stonewall, TX
# 3101                   $300          Cottle    TX         Cottle, TX
# 3102                   $280        McDowell    WV       McDowell, WV
# 3103                   $280         Cochran    TX        Cochran, TX
# 3104                   $240            Todd    SD           Todd, SD
#
# [3105 rows x 6 columns]

# %%
housing_prices["COUNTY_ID"] = housing_prices["COUNTY"] + ", " + housing_prices["STATE"]

# %%
housing_prices
# Out:
#      Median Home Price Q4 2023 Monthly Payment Q4 2023  \
# 0                  $1,575,350                  $9,720
# 1                  $1,553,450                  $9,580
# 2                  $1,456,190                  $8,980
# 3                  $1,334,250                  $8,230
# 4                  $1,181,140                  $7,290
# ...                        ...                     ...
# 3100                  $56,440                    $350
# 3101                  $53,040                    $330
# 3102                  $50,740                    $310
# 3103                  $49,530                    $310
# 3104                  $42,660                    $260
#
#      Monthly Payment Q4 2022         COUNTY STATE          COUNTY_ID
# 0                    $9,210       San Mateo    CA      San Mateo, CA
# 1                    $8,570     Santa Clara    CA    Santa Clara, CA
# 2                    $8,520           Marin    CA          Marin, CA
# 3                    $7,800   San Francisco    CA  San Francisco, CA
# 4                    $6,610           Teton    WY          Teton, WY
# ...                      ...            ...   ...                ...
# 3100                   $320       Stonewall    TX      Stonewall, TX
# 3101                   $300          Cottle    TX         Cottle, TX
# 3102                   $280        McDowell    WV       McDowell, WV
# 3103                   $280         Cochran    TX        Cochran, TX
# 3104                   $240            Todd    SD           Todd, SD
#
# [3105 rows x 6 columns]

# %%
counties
# Out:
#               GEO_ID STATE COUNTY            NAME     LSAD  CENSUSAREA  \
# 0     0500000US02261    02    261  Valdez-Cordova       CA   34239.880
# 1     0500000US02270    02    270    Wade Hampton       CA   17081.433
# 2     0500000US02275    02    275        Wrangell  Cty&Bor    2541.483
# 3     0500000US02290    02    290   Yukon-Koyukuk       CA  145504.789
# 4     0500000US04003    04    003         Cochise   County    6165.690
# ...              ...   ...    ...             ...      ...         ...
# 3216  0500000US50025    50    025         Windham   County     785.305
# 3217  0500000US50027    50    027         Windsor   County     969.337
# 3218  0500000US51001    51    001        Accomack   County     449.496
# 3219  0500000US51005    51    005       Alleghany   County     445.457
# 3220  0500000US51007    51    007          Amelia   County     355.269
#
#                                                geometry
# 0     MULTIPOLYGON (((-147.48383 60.61864, -147.5000...
# 1     POLYGON ((-162.58775 63.27573, -162.55188 63.2...
# 2     MULTIPOLYGON (((-132.56989 56.63350, -132.5703...
# 3     POLYGON ((-141.00246 65.83942, -141.09244 65.8...
# 4     POLYGON ((-109.04761 32.42638, -109.04829 32.0...
# ...                                                 ...
# 3216  POLYGON ((-72.43447 43.23043, -72.43766 43.225...
# 3217  POLYGON ((-72.43380 43.23300, -72.43497 43.233...
# 3218  MULTIPOLYGON (((-75.97361 37.83582, -75.97171 ...
# 3219  POLYGON ((-80.29614 37.69178, -80.29411 37.693...
# 3220  POLYGON ((-77.85515 37.41836, -77.87549 37.416...
#
# [3221 rows x 7 columns]

# %%
state_codes = {
    '12': 'FL', '56': 'WY', '72': 'PR', '34': 'NJ', '35': 'NM', '48': 'TX',
    '53': 'WA', '10': 'DE', '11': 'DC', '55': 'WI', '54': 'WV', '15': 'HI',
    '22': 'LA', '37': 'NC', '38': 'ND', '31': 'NE', '47': 'TN', '36': 'NY',
    '42': 'PA', '02': 'AK', '32': 'NV', '33': 'NH', '51': 'VA', '08': 'CO',
    '06': 'CA', '01': 'AL', '05': 'AR', '50': 'VT', '17': 'IL', '13': 'GA',
    '18': 'IN', '19': 'IA', '25': 'MA', '04': 'AZ', '16': 'ID', '09': 'CT',
    '23': 'ME', '24': 'MD', '40': 'OK', '39': 'OH', '49': 'UT', '29': 'MO',
    '27': 'MN', '26': 'MI', '44': 'RI', '20': 'KS', '30': 'MT', '28': 'MS',
    '45': 'SC', '21': 'KY', '41': 'OR', '46': 'SD'
}

# %%
counties['STATE'] = counties['STATE'].replace(state_codes)

# %%
# Create a unique identifier for each county in the shapefile
counties['COUNTY_ID'] = counties['NAME'] + ', ' + counties['STATE']

# %%
counties
# Out:
#               GEO_ID STATE COUNTY            NAME     LSAD  CENSUSAREA  \
# 0     0500000US02261    AK    261  Valdez-Cordova       CA   34239.880
# 1     0500000US02270    AK    270    Wade Hampton       CA   17081.433
# 2     0500000US02275    AK    275        Wrangell  Cty&Bor    2541.483
# 3     0500000US02290    AK    290   Yukon-Koyukuk       CA  145504.789
# 4     0500000US04003    AZ    003         Cochise   County    6165.690
# ...              ...   ...    ...             ...      ...         ...
# 3216  0500000US50025    VT    025         Windham   County     785.305
# 3217  0500000US50027    VT    027         Windsor   County     969.337
# 3218  0500000US51001    VA    001        Accomack   County     449.496
# 3219  0500000US51005    VA    005       Alleghany   County     445.457
# 3220  0500000US51007    VA    007          Amelia   County     355.269
#
#                                                geometry           COUNTY_ID
# 0     MULTIPOLYGON (((-147.48383 60.61864, -147.5000...  Valdez-Cordova, AK
# 1     POLYGON ((-162.58775 63.27573, -162.55188 63.2...    Wade Hampton, AK
# 2     MULTIPOLYGON (((-132.56989 56.63350, -132.5703...        Wrangell, AK
# 3     POLYGON ((-141.00246 65.83942, -141.09244 65.8...   Yukon-Koyukuk, AK
# 4     POLYGON ((-109.04761 32.42638, -109.04829 32.0...         Cochise, AZ
# ...                                                 ...                 ...
# 3216  POLYGON ((-72.43447 43.23043, -72.43766 43.225...         Windham, VT
# 3217  POLYGON ((-72.43380 43.23300, -72.43497 43.233...         Windsor, VT
# 3218  MULTIPOLYGON (((-75.97361 37.83582, -75.97171 ...        Accomack, VA
# 3219  POLYGON ((-80.29614 37.69178, -80.29411 37.693...       Alleghany, VA
# 3220  POLYGON ((-77.85515 37.41836, -77.87549 37.416...          Amelia, VA
#
# [3221 rows x 8 columns]

# %%
housing_prices = housing_prices.drop(columns=["STATE","COUNTY"])
housing_prices
# Out:
#      Median Home Price Q4 2023 Monthly Payment Q4 2023  \
# 0                  $1,575,350                  $9,720
# 1                  $1,553,450                  $9,580
# 2                  $1,456,190                  $8,980
# 3                  $1,334,250                  $8,230
# 4                  $1,181,140                  $7,290
# ...                        ...                     ...
# 3100                  $56,440                    $350
# 3101                  $53,040                    $330
# 3102                  $50,740                    $310
# 3103                  $49,530                    $310
# 3104                  $42,660                    $260
#
#      Monthly Payment Q4 2022          COUNTY_ID
# 0                    $9,210       San Mateo, CA
# 1                    $8,570     Santa Clara, CA
# 2                    $8,520           Marin, CA
# 3                    $7,800   San Francisco, CA
# 4                    $6,610           Teton, WY
# ...                      ...                ...
# 3100                   $320       Stonewall, TX
# 3101                   $300          Cottle, TX
# 3102                   $280        McDowell, WV
# 3103                   $280         Cochran, TX
# 3104                   $240            Todd, SD
#
# [3105 rows x 4 columns]

# %%
# Join the housing prices data with the county boundaries
merged = counties.set_index("COUNTY_ID").join(housing_prices.set_index("COUNTY_ID"))

# %%
merged["Median Home Price Q4 2023"] = merged["Median Home Price Q4 2023"].str.replace(',', '').str.replace('$', '').astype(float)
# merged["Monthly Payment Q4 2022"]
# merged["Monthly Payment Q4 2023"]
merged
# Out:
#                             GEO_ID STATE COUNTY            NAME     LSAD  \
# COUNTY_ID
# Valdez-Cordova, AK  0500000US02261    AK    261  Valdez-Cordova       CA
# Wade Hampton, AK    0500000US02270    AK    270    Wade Hampton       CA
# Wrangell, AK        0500000US02275    AK    275        Wrangell  Cty&Bor
# Yukon-Koyukuk, AK   0500000US02290    AK    290   Yukon-Koyukuk       CA
# Cochise, AZ         0500000US04003    AZ    003         Cochise   County
# ...                            ...   ...    ...             ...      ...
# Windham, VT         0500000US50025    VT    025         Windham   County
# Windsor, VT         0500000US50027    VT    027         Windsor   County
# Accomack, VA        0500000US51001    VA    001        Accomack   County
# Alleghany, VA       0500000US51005    VA    005       Alleghany   County
# Amelia, VA          0500000US51007    VA    007          Amelia   County
#
#                     CENSUSAREA  \
# COUNTY_ID
# Valdez-Cordova, AK   34239.880
# Wade Hampton, AK     17081.433
# Wrangell, AK          2541.483
# Yukon-Koyukuk, AK   145504.789
# Cochise, AZ           6165.690
# ...                        ...
# Windham, VT            785.305
# Windsor, VT            969.337
# Accomack, VA           449.496
# Alleghany, VA          445.457
# Amelia, VA             355.269
#
#                                                              geometry  \
# COUNTY_ID
# Valdez-Cordova, AK  MULTIPOLYGON (((-147.48383 60.61864, -147.5000...
# Wade Hampton, AK    POLYGON ((-162.58775 63.27573, -162.55188 63.2...
# Wrangell, AK        MULTIPOLYGON (((-132.56989 56.63350, -132.5703...
# Yukon-Koyukuk, AK   POLYGON ((-141.00246 65.83942, -141.09244 65.8...
# Cochise, AZ         POLYGON ((-109.04761 32.42638, -109.04829 32.0...
# ...                                                               ...
# Windham, VT         POLYGON ((-72.43447 43.23043, -72.43766 43.225...
# Windsor, VT         POLYGON ((-72.43380 43.23300, -72.43497 43.233...
# Accomack, VA        MULTIPOLYGON (((-75.97361 37.83582, -75.97171 ...
# Alleghany, VA       POLYGON ((-80.29614 37.69178, -80.29411 37.693...
# Amelia, VA          POLYGON ((-77.85515 37.41836, -77.87549 37.416...
#
#                     Median Home Price Q4 2023 Monthly Payment Q4 2023  \
# COUNTY_ID
# Valdez-Cordova, AK                        NaN                     NaN
# Wade Hampton, AK                          NaN                     NaN
# Wrangell, AK                              NaN                     NaN
# Yukon-Koyukuk, AK                         NaN                     NaN
# Cochise, AZ                          220550.0                 $1,360
# ...                                       ...                     ...
# Windham, VT                          279810.0                 $1,730
# Windsor, VT                          279470.0                 $1,720
# Accomack, VA                         198300.0                 $1,220
# Alleghany, VA                        132850.0                   $820
# Amelia, VA                           254370.0                 $1,570
#
#                    Monthly Payment Q4 2022
# COUNTY_ID
# Valdez-Cordova, AK                     NaN
# Wade Hampton, AK                       NaN
# Wrangell, AK                           NaN
# Yukon-Koyukuk, AK                      NaN
# Cochise, AZ                        $1,240
# ...                                    ...
# Windham, VT                        $1,450
# Windsor, VT                        $1,450
# Accomack, VA                       $1,070
# Alleghany, VA                        $720
# Amelia, VA                         $1,360
#
# [3221 rows x 10 columns]

# %%
merged.to_csv("merged.csv",index=False)

# %%
import json
from shapely.geometry import mapping

# Function to convert Shapely geometry to GeoJSON
def geometry_to_geojson(geometry):
    if geometry:
        return json.loads(json.dumps(mapping(geometry)))
    else:
        return None

# Convert the 'geometry' column to GeoJSON format
df['geojson'] = df['geometry'].apply(geometry_to_geojson)

# Create the choropleth map
fig = plotly.express.choropleth_mapbox(
    df,
    geojson=df['geojson'],  # Use the 'geojson' column
    locations='GEO_ID',
    color='Median Home Price Q4 2023',
    range_color=[df['Median Home Price Q4 2023'].min(), df['Median Home Price Q4 2023'].max()],
    mapbox_style="open-street-map",
    title='Median Home Price Q4 2023 by County'
)

fig.update_layout(margin=dict(l=0, r=0, t=50, b=0))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 59
#      48     fig = plotly.express.choropleth_mapbox(
#      49         df,
#      50         geojson=df['geometry'],  # Use the parsed geometry column
#    (...)
#      55         title='Median Home Price Q4 2023 by County'
#      56     )
#      58     fig.update_layout(margin=dict(l=0, r=0, t=50, b=0))
# ---> 59     fig.show()
#      60 else:
#      61     print("Failed to create geometry column. Check for errors in data parsing.")
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)
#    3406 None
#    3407 """
#    3408 import plotly.io as pio
# -> 3410 return pio.show(self, *args, **kwargs)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\io\_renderers.py:386, in show(fig, renderer, validate, **kwargs)
#     383 fig_dict = validate_coerce_fig_to_dict(fig, validate)
#     385 # Mimetype renderers
# --> 386 bundle = renderers._build_mime_bundle(fig_dict, renderers_string=renderer, **kwargs)
#     387 if bundle:
#     388     if not ipython_display:
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\io\_renderers.py:294, in RenderersConfig._build_mime_bundle(self, fig_dict, renderers_string, **kwargs)
#     291             if hasattr(renderer, k):
#     292                 setattr(renderer, k, v)
# --> 294         bundle.update(renderer.to_mimebundle(fig_dict))
#     296 return bundle
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\io\_base_renderers.py:94, in PlotlyRenderer.to_mimebundle(self, fig_dict)
#      90 if config:
#      91     fig_dict["config"] = config
#      93 json_compatible_fig_dict = json.loads(
# ---> 94     to_json(fig_dict, validate=False, remove_uids=False)
#      95 )
#      97 return {"application/vnd.plotly.v1+json": json_compatible_fig_dict}
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\io\_json.py:221, in to_json(fig, validate, pretty, remove_uids, engine)
#     218     for trace in fig_dict.get("data", []):
#     219         trace.pop("uid", None)
# --> 221 return to_json_plotly(fig_dict, pretty=pretty, engine=engine)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\io\_json.py:142, in to_json_plotly(plotly_object, pretty, engine)
#     137         opts["separators"] = (",", ":")
#     139     from _plotly_utils.utils import PlotlyJSONEncoder
#     141     return _safe(
# --> 142         json.dumps(plotly_object, cls=PlotlyJSONEncoder, **opts), _swap_json
#     143     )
#     144 elif engine == "orjson":
#     145     JsonConfig.validate_orjson()
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\_plotly_utils\utils.py:56, in PlotlyJSONEncoder.encode(self, o)
#      49 """
#      50 Load and then dump the result using parse_constant kwarg
#      51
#      52 Note that setting invalid separators will cause a failure at this step.
#      53
#      54 """
#      55 # this will raise errors in a normal-expected way
# ---> 56 encoded_o = super(PlotlyJSONEncoder, self).encode(o)
#      57 # Brute force guessing whether NaN or Infinity values are in the string
#      58 # We catch false positive cases (e.g. strings such as titles, labels etc.)
#      59 # but this is ok since the intention is to skip the decoding / reencoding
#      60 # step when it's completely safe
#      62 if not ("NaN" in encoded_o or "Infinity" in encoded_o):
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\json\encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\json\encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     253 else:
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\_plotly_utils\utils.py:133, in PlotlyJSONEncoder.default(self, obj)
#     131     except NotEncodable:
#     132         pass
# --> 133 return _json.JSONEncoder.default(self, obj)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)
#     178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type MultiPolygon is not JSON serializable
